# %%
from pathlib import Path

# Step 1: Create folder in Documents
output_dir = Path.home() / "Documents" / "PythonFiles"
output_dir.mkdir(parents=True, exist_ok=True)

# Step 2: File path
file_path = output_dir / "Act5_example.txt"

# Step 3: Write to file
with open(file_path, "w", encoding="utf-8") as file:
    file.write("Hello, Welcome to Python Programming!\n")
    file.write("File saved safely with pathlib.\n")
    file.write("Python makes file handling easy!")

# Step 4: Confirm
print(f"File saved to: {file_path.resolve()}")
# Out:
# File saved to: /root/Documents/PythonFiles/Act5_example.txt

# %%
from pathlib import Path

output_dir = Path.home() / "Documents" / "Bolanos_Activity_5"
output_dir.mkdir(exist_ok=True)

file_path = output_dir / "Act5_example.txt"

with open(file_path, "w", encoding="utf-8") as file:
    file.write("Hello, Welcome to Python Programming!\n")
    file.write("File saved safely with pathlib.\n")
    file.write("Python makes file handling easy!")

print("Updated folder and file created.")
# Out:
# Updated folder and file created.

# %%
from pathlib import Path

file_path = Path.home() / "Documents" / "PythonFiles" / "Act5_example.txt"

# Read full content
if file_path.exists():
    with open(file_path, "r", encoding="utf-8") as file:
        content = file.read()
    print("File content:\n", content)

# Read line by line
if file_path.exists():
    with open(file_path, "r", encoding="utf-8") as file:
        for line_number, line in enumerate(file, 1):
            print(f"Line {line_number}: {line.strip()}")
# Out:
# File content:
#  Hello, Welcome to Python Programming!
# File saved safely with pathlib.
# Python makes file handling easy!
# Line 1: Hello, Welcome to Python Programming!
# Line 2: File saved safely with pathlib.
# Line 3: Python makes file handling easy!

# %%
from pathlib import Path

file_path = Path.home() / "Documents" / "PythonFiles" / "Act5_example.txt"

with open(file_path, "r", encoding="utf-8") as file:
    for line in file:
        if "Python" in line:
            print("Filtered line:", line.strip())

print("\nWord count per line:")
with open(file_path, "r", encoding="utf-8") as file:
    for i, line in enumerate(file, 1):
        words = len(line.split())
        print(f"Line {i}: {words} words")
# Out:
# Filtered line: Hello, Welcome to Python Programming!
# Filtered line: Python makes file handling easy!
#
# Word count per line:
# Line 1: 5 words
# Line 2: 5 words
# Line 3: 5 words

# %%
from pathlib import Path

file_path = Path.home() / "Documents" / "PythonFiles" / "Act5_example.txt"

with open(file_path, "a", encoding="utf-8") as file:
    file.write("\nThis line was added!")

print("Data appended successfully.")
# Out:
# Data appended successfully.

# %%
from pathlib import Path

file_path = Path.home() / "Documents" / "PythonFiles" / "Act5_example.txt"

file_path.parent.mkdir(parents=True, exist_ok=True)

lines = [
    "This is line 1 from a list.",
    "This is line 2 from a list.",
    "This is line 3 from a list."
]

with open(file_path, "a", encoding="utf-8") as file:
    file.writelines([line + "\n" for line in lines])

print("Multiple lines appended successfully.")

user_input = input("Enter text to append: ")

with open(file_path, "a", encoding="utf-8") as file:
    file.write(user_input + "\n")
# Out:
# Multiple lines appended successfully.
# Enter text to append: Honda Civic

# %%
from pathlib import Path
from datetime import datetime
import shutil

backup_dir = Path.home() / "Documents" / "PythonFiles"
backup_dir.mkdir(exist_ok=True)

def write_with_backup(filename: str, content: str):
    file_path = backup_dir / filename

    # Backup if exists
    if file_path.exists():
        timestamp = datetime.now().strftime("%Y%m%d_%H%M%S")
        backup_path = file_path.with_name(
            f"{file_path.stem}_backup_{timestamp}{file_path.suffix}"
        )
        shutil.copy2(file_path, backup_path)
        print(f"Backup saved: {backup_path.name}")

    # Write new content
    with open(file_path, "w", encoding="utf-8") as file:
        file.write(content)

    print(f"File saved: {file_path.name}")


def read_file(filename: str):
    file_path = backup_dir / filename
    with open(file_path, "r", encoding="utf-8") as file:
        return file.read()


print("=== Demo ===")
write_with_backup("demo.txt", "Initial content")
write_with_backup("demo.txt", "Updated content")

print(read_file("demo.txt"))

print("\nBackups:")
for b in backup_dir.glob("*backup*"):
    print("-", b.name)
# Out:
# === Demo ===
# File saved: demo.txt
# Backup saved: demo_backup_20260504_033237.txt
# File saved: demo.txt
# Updated content
#
# Backups:
# - demo_backup_20260504_033237.txt

# %%
from pathlib import Path
from datetime import datetime
import shutil

backup_dir = Path.home() / "Documents" / "PythonFiles"
backup_dir.mkdir(exist_ok=True)

def file_manager():
    file_name = input("Enter filename (e.g., notes.txt): ")
    file_path = backup_dir / file_name

    while True:
        print("\n--- MENU ---")
        print("1. Write to file")
        print("2. Append to file")
        print("3. Read file")
        print("4. Backup file")
        print("5. Exit")

        choice = input("Choose an option (1-5): ")

        if choice == "1":
            content = input("Enter content to write:\n")
            with open(file_path, "w", encoding="utf-8") as f:
                f.write(content)
            print("File written successfully.")

        elif choice == "2":
            more = input("Enter content to append:\n")
            with open(file_path, "a", encoding="utf-8") as f:
                f.write("\n" + more)
            print("Content appended.")

        elif choice == "3":
            if file_path.exists():
                with open(file_path, "r", encoding="utf-8") as f:
                    print("\nFile Content:\n", f.read())
            else:
                print("File not found.")

        elif choice == "4":
            if file_path.exists():
                timestamp = datetime.now().strftime("%Y%m%d_%H%M%S")
                backup_file = file_path.with_name(
                    f"{file_path.stem}_backup_{timestamp}{file_path.suffix}"
                )
                shutil.copy2(file_path, backup_file)
                print(f"Backup created: {backup_file.name}")
            else:
                print("Cannot backup. File does not exist.")

        elif choice == "5":
            print("Exiting file manager.")
            break

        else:
            print("Invalid choice.")


if __name__ == "__main__":
    file_manager()
# Out:
# Enter filename (e.g., notes.txt): gizmo.txt
#
# --- MENU ---
# 1. Write to file
# 2. Append to file
# 3. Read file
# 4. Backup file
# 5. Exit
# Choose an option (1-5): 1
# Enter content to write:
# beelzebub
# File written successfully.
#
# --- MENU ---
# 1. Write to file
# 2. Append to file
# 3. Read file
# 4. Backup file
# 5. Exit
# Choose an option (1-5): 5
# Exiting file manager.

# %%
from pathlib import Path
from datetime import datetime
import shutil

# 🔁 CHANGE THIS TO YOUR SURNAME
SURNAME = "Bolanos"

# Custom directory
backup_dir = Path.home() / "Documents" / "Bolanos_Activity_5"
backup_dir.mkdir(exist_ok=True)

def file_manager():
    file_name = input("Enter filename (e.g., notes.txt, data.csv, readme.md): ")
    file_path = backup_dir / file_name

    while True:
        print("\n--- MENU ---")
        print("1. Write to file")
        print("2. Append to file")
        print("3. Read file")
        print("4. Backup file")
        print("5. Exit")
        print("6. List backup files")

        choice = input("Choose an option (1-6): ")

        if choice == "1":
            content = input("Enter content to write:\n")
            with open(file_path, "w", encoding="utf-8") as f:
                f.write(content)
            print("File written successfully.")

        elif choice == "2":
            more = input("Enter content to append:\n")
            with open(file_path, "a", encoding="utf-8") as f:
                f.write("\n" + more)
            print("Content appended.")

        elif choice == "3":
            if file_path.exists():
                with open(file_path, "r", encoding="utf-8") as f:
                    print("\nFile Content:\n", f.read())
            else:
                print("File not found.")

        elif choice == "4":
            if file_path.exists():
                timestamp = datetime.now().strftime("%Y%m%d_%H%M%S")
                backup_file = file_path.with_name(
                    f"{file_path.stem}_{SURNAME}_backup_{timestamp}{file_path.suffix}"
                )
                shutil.copy2(file_path, backup_file)
                print(f"Backup created: {backup_file.name}")
            else:
                print("Cannot backup. File does not exist.")

        elif choice == "5":
            print("Exiting the file manager.")
            break

        elif choice == "6":
            print("\nBackup files:")
            files = list(backup_dir.glob("*backup*"))

            if files:
                for file in files:
                    print("-", file.name)
            else:
                print("No backup files found.")

        else:
            print("Invalid choice. Please try again.")


# Run program
if __name__ == "__main__":
    file_manager()
# Out:
# Enter filename (e.g., notes.txt, data.csv, readme.md): pokemon.txt
#
# --- MENU ---
# 1. Write to file
# 2. Append to file
# 3. Read file
# 4. Backup file
# 5. Exit
# 6. List backup files
# Choose an option (1-6): 1
# Enter content to write:
# dragonite
# File written successfully.
#
# --- MENU ---
# 1. Write to file
# 2. Append to file
# 3. Read file
# 4. Backup file
# 5. Exit
# 6. List backup files
# Choose an option (1-6): 4
# Backup created: pokemon_Bolanos_backup_20260504_033455.txt
#
# --- MENU ---
# 1. Write to file
# 2. Append to file
# 3. Read file
# 4. Backup file
# 5. Exit
# 6. List backup files
# Choose an option (1-6): ivysaur
# Invalid choice. Please try again.
#
# --- MENU ---
# 1. Write to file
# 2. Append to file
# 3. Read file
# 4. Backup file
# 5. Exit
# 6. List backup files
# Choose an option (1-6): 4
# Backup created: pokemon_Bolanos_backup_20260504_033511.txt
#
# --- MENU ---
# 1. Write to file
# 2. Append to file
# 3. Read file
# 4. Backup file
# 5. Exit
# 6. List backup files
# Choose an option (1-6): 6
#
# Backup files:
# - pokemon_Bolanos_backup_20260504_033511.txt
# - pokemon_Bolanos_backup_20260504_033455.txt
#
# --- MENU ---
# 1. Write to file
# 2. Append to file
# 3. Read file
# 4. Backup file
# 5. Exit
# 6. List backup files
# Choose an option (1-6): 5
# Exiting the file manager.
